# %%
#ejercicio1
#definir códigos
tele = ("0001", 520000)
lava = ("0002", 380000) 
refri = ("0003", 420000)
cama = ("0104", 180000)
tosta =("3005", 50000)
licua = ("5010", 20000)

tupla = (tele,lava,refri,cama,tosta,licua)

#Mostrar productos
articulos= {"Televisión":["0001", 520000],
            "Lavadora":["0002", 380000],
            "Refrigeradora":["0003", 420000],
            "Cama":["0104", 180000],
            "Tostatadora":["3005", 50000],
            "Licuadora":["5010", 20000]}

print("Item Código Precio\n",articulos)
#primer código
a=  input(" Ingrese el código aquí: ")
b= a in tupla[0]
d= a in tupla[1]
f= a in tupla[2]
g= a in tupla[3]
h= a in tupla[4]
i= a in tupla[5]
if b == True: c= tupla[0][1]
elif d == True: c= tupla[1][1]
elif f == True: c= tupla[2][1]
elif g == True: c= tupla[3][1]
elif h == True: c= tupla[4][1]
elif i == True: c= tupla[5][1]
else:
  c=0 
  print("No existe un producto con el código que ha ingresado")

#segundo código
e=  input(" Ingrese el código aquí: ")
b1= e in tupla[0]
d1= e in tupla[1]
f1= e in tupla[2]
g1= e in tupla[3]
h1= e in tupla[4]
i1= e in tupla[5]
if b1 == True: c1= tupla[0][1]
elif d1 == True: c1= tupla[1][1]
elif f1 == True: c1= tupla[2][1]
elif g1 == True: c1= tupla[3][1]
elif h1 == True: c1= tupla[4][1]
elif i1 == True: c1= tupla[5][1]
else:
  c1=0 
  print("No existe un producto con el código que ha ingresado")

#tercer código
e1=  input(" Ingrese el código aquí: ")
b2= e1 in tupla[0]
d2= e1 in tupla[1]
f2= e1 in tupla[2]
g2= e1 in tupla[3]
h2= e1 in tupla[4]
i2= e1 in tupla[5]
if b2 == True: c2= tupla[0][1]
elif d2 == True: c2= tupla[1][1]
elif f2 == True: c2= tupla[2][1]
elif g2 == True: c2= tupla[3][1]
elif h2 == True: c2= tupla[4][1]
elif i2 == True: c2= tupla[5][1]
else:
  c2=0 
  print("No existe un producto con el código que ha ingresado")

#cuarto código
e2=  input(" Ingrese el código aquí: ")
b3= e2 in tupla[0]
d3= e2 in tupla[1]
f3= e2 in tupla[2]
g3= e2 in tupla[3]
h3= e2 in tupla[4]
i3= e2 in tupla[5]
if b3 == True: c3= tupla[0][1]
elif d3 == True: c3= tupla[1][1]
elif f3 == True: c3= tupla[2][1]
elif g3 == True: c3= tupla[3][1]
elif h3 == True: c3= tupla[4][1]
elif i3 == True: c3= tupla[5][1]
else:
  c3=0 
  print("No existe un producto que corresponda al código ingresado")

suma = c + c1 + c2 + c3

#confirmar si es cliente regular
escliente= input("¿Es cliente regular?(Y/N):  ")
if escliente == "Y": print("Es cliente regular\nMonto total a pagar: ",int(suma -suma/ 10))
else: print("No es cliente regular\nMonto total a pagar:",suma)
# Out:
# Item Código Precio
#  {'Televisión': ['0001', 520000], 'Lavadora': ['0002', 380000], 'Refrigeradora': ['0003', 420000], 'Cama': ['0104', 180000], 'Tostatadora': ['3005', 50000], 'Licuadora': ['5010', 20000]}
#  Ingrese el código aquí: 0001
#  Ingrese el código aquí: 0002
#  Ingrese el código aquí: 0003
#  Ingrese el código aquí: 0004
# No existe un producto que corresponda al código ingresado
# ¿Es cliente regular?(Y/N):  5010
# No es cliente regular
# Monto total a pagar: 1320000

# %%
#ejercicio2
print("Insertar número de cinco dígitos")
numero= int(input())
#comprobar que sean pares
comprobar_pares = numero % 10
pares = (2,4,6,8)
#sacar el número par
if comprobar_pares in pares: p = comprobar_pares
else: p= 0
sacar_dms= numero // 10
#sacar el número par nuevamente
comprobar_pares = sacar_dms % 10
if comprobar_pares in pares: p1 = comprobar_pares
else: p1= 0
sacar_dms= sacar_dms // 10

comprobar_pares = sacar_dms % 10
if comprobar_pares in pares: p2 = comprobar_pares
else: p2= 0
sacar_dms= sacar_dms // 10

comprobar_pares = sacar_dms % 10
if comprobar_pares in pares: p3 = comprobar_pares
else: p3= 0
sacar_dms= sacar_dms // 10

comprobar_pares = sacar_dms % 10
if comprobar_pares in pares: p4 = comprobar_pares
else: p4= 0
sacar_dms= sacar_dms // 10

#sumar pares
sumapares= p+p1+p2+p3+p4
print("Resultado:",sumapares)
# Out:
# Insertar número de cinco dígitos
# 00022
# Resultado: 4

# %%
#ejercicio1 extra: este no tiene diccionarios, pero me gustaría compartirlo porque me gustó como quedó la lissta de productos.
#definir códigos
tele = ("0001", 520000)
lava = ("0002", 380000) 
refri = ("0003", 420000)
cama = ("0104", 180000)
tosta =("3005", 50000)
licua = ("5010", 20000)

tupla = (tele,lava,refri,cama,tosta,licua)

#Mostrar productos
productos ="Item           Código  Precio\n Televisión     0001    520 000\n Lavadora       0002    380 000\n Refrigeradora  0003    420 000\n Cama           0104    180 000\n Tostadora      3005     50 000\n licuadora      5010     20 000"
print(" Lista de productos\n", productos)


#primer código
a=  input(" Ingrese el código aquí: ")
b= a in tupla[0]
d= a in tupla[1]
f= a in tupla[2]
g= a in tupla[3]
h= a in tupla[4]
i= a in tupla[5]
if b == True: c= tupla[0][1]
elif d == True: c= tupla[1][1]
elif f == True: c= tupla[2][1]
elif g == True: c= tupla[3][1]
elif h == True: c= tupla[4][1]
elif i == True: c= tupla[5][1]
else:
  c=0 
  print("No existe un producto con el código que ha ingresado")

#segundo código
e=  input(" Ingrese el código aquí: ")
b1= e in tupla[0]
d1= e in tupla[1]
f1= e in tupla[2]
g1= e in tupla[3]
h1= e in tupla[4]
i1= e in tupla[5]
if b1 == True: c1= tupla[0][1]
elif d1 == True: c1= tupla[1][1]
elif f1 == True: c1= tupla[2][1]
elif g1 == True: c1= tupla[3][1]
elif h1 == True: c1= tupla[4][1]
elif i1 == True: c1= tupla[5][1]
else:
  c1=0 
  print("No existe un producto con el código que ha ingresado")

#tercer código
e1=  input(" Ingrese el código aquí: ")
b2= e1 in tupla[0]
d2= e1 in tupla[1]
f2= e1 in tupla[2]
g2= e1 in tupla[3]
h2= e1 in tupla[4]
i2= e1 in tupla[5]
if b2 == True: c2= tupla[0][1]
elif d2 == True: c2= tupla[1][1]
elif f2 == True: c2= tupla[2][1]
elif g2 == True: c2= tupla[3][1]
elif h2 == True: c2= tupla[4][1]
elif i2 == True: c2= tupla[5][1]
else:
  c2=0 
  print("No existe un producto con el código que ha ingresado")

#cuarto código
e2=  input(" Ingrese el código aquí: ")
b3= e2 in tupla[0]
d3= e2 in tupla[1]
f3= e2 in tupla[2]
g3= e2 in tupla[3]
h3= e2 in tupla[4]
i3= e2 in tupla[5]
if b3 == True: c3= tupla[0][1]
elif d3 == True: c3= tupla[1][1]
elif f3 == True: c3= tupla[2][1]
elif g3 == True: c3= tupla[3][1]
elif h3 == True: c3= tupla[4][1]
elif i3 == True: c3= tupla[5][1]
else:
  c3=0 
  print("No existe un producto que corresponda al código ingresado")

suma = c + c1 + c2 + c3

#confirmar si es cliente regular
escliente= input("¿Es cliente regular?(Y/N):  ")
if escliente == "Y": print("Es cliente regular\nMonto total a pagar: ",int(suma -suma/ 10))
else: print("No es cliente regular\nMonto total a pagar:",suma)
# Out:
#  Lista de productos
#  Item           Código  Precio
#  Televisión     0001    520 000
#  Lavadora       0002    380 000
#  Refrigeradora  0003    420 000
#  Cama           0104    180 000
#  Tostadora      3005     50 000
#  licuadora      5010     20 000
#  Ingrese el código aquí: 0001
#  Ingrese el código aquí: 0002
#  Ingrese el código aquí: 5010
#  Ingrese el código aquí: 3005
# ¿Es cliente regular?(Y/N):  Y
# Es cliente regular
# Monto total a pagar:  873000
